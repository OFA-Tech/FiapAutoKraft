# %%
from roboflow import Roboflow
rf = Roboflow(api_key="fqk1AgymgVCZC72Dxu9D")
project = rf.workspace("caitos-personal").project("challenge2025-spi-ee60h")
version = project.version(2)
dataset = version.download("yolov12")
# Out:
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File C:\Program Files\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
# ...

# %%
import torch
print(torch.cuda.is_available())      # should be True
print(torch.version.cuda)             # should show 12.6 (or similar)
print(torch.cuda.get_device_name(0))  # “NVIDIA GeForce RTX 3070…”
# Out:
# False
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(torch.cuda.is_available())      # should be True
#       3 print(torch.version.cuda)             # should show 12.6 (or similar)
# ----> 4 print(torch.cuda.get_device_name(0))  # “NVIDIA GeForce RTX 3070…”
#
# File C:\Dev\OFA-Tech\FiapAutoKraft\Console-ComputationalVision\.venv\Lib\site-packages\torch\cuda\__init__.py:584, in get_device_name(device)
#     572 def get_device_name(device: "Device" = None) -> str:
#     573     r"""Get the name of a device.
#     574
#     575     Args:
#    (...)    582         str: the name of the device
#     583     """
# --> 584     return get_device_properties(device).name
#
# File C:\Dev\OFA-Tech\FiapAutoKraft\Console-ComputationalVision\.venv\Lib\site-packages\torch\cuda\__init__.py:616, in get_device_properties(device)
# ...

# %%
# !yolo task=detect model=yolo12s.pt data=Console-ComputationalVision/datasets/Challenge2025-SPI_moday_29_09/data.yaml epochs=100 imgsz=640 plots=True
